# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['font.family'] = 'CM Roman'
matplotlib.rcParams['font.size'] = 12

# %%
#data
V_in = np.array([66.2,66.4,66.6,66.8,67.0,67.5,68.0])
V_out = np.array([13,20,26,33,39,54,68])
V_err = np.array([5,5,5,10,10,10,10])

#linear fit
res = stats.linregress(V_in, V_out)
x = np.linspace(65.5,68.5,100)

#zero line
y_0 = np.zeros(len(x))

# %%
#Figure
fig, ax = plt.subplots()

ax.errorbar(V_in, V_out, V_err, color='r', fmt='o', capsize=4, label='Data')
ax.plot(x, res.intercept + res.slope*x,color='r', linestyle='--', label='Data fit')
ax.plot(x,y_0, color='k', alpha=0.7,linestyle='--')
ax.set_xlim([65.5,68.5])
ax.set_xlabel(r'$V_{in} (V)$')
ax.set_ylabel(r'$V_{out} (mV)$')
ax.set_title('Diode Gain')
ax.legend()

fig.savefig('../../Images/Diode_Gain.pdf')

# %%
#find the zeros
breakdown = -res.intercept/res.slope
print('Voltage breakdown:', breakdown, 'V')
# Out:
# Voltage breakdown: 65.74413418654257 V
